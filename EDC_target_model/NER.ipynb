# %%
import json
import csv

# Load the JSON data
with open('../EDC_target_model/EDC_annotations.json', 'r') as f:
    data = json.load(f)

annotations = data['annotations']

# %%
annotations
# Out:
# [None,
#  ['This is largely driven by anthropogenic changes to the environment, including the widespread exposure of invertebrates to endocrine disrupting chemicals (EDCs), which impair fertility.\r',
#   {'entities': [[122, 152, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [154, 158, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['To test whether generations of Drosophila melanogaster born from parents exposed to a common dietary EDC, equol, could recover reproductive function, we quantified the reproductive capacity of the two subsequent generations.\r',
#   {'entities': [[101, 104, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [106, 111, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  ['Though the sex ratio alters in response to EDC exposure, favouring the survival of female offspring, most lineages with ancestral EDC exposure exhibit persistent subfertility in both the male and female.\r',
#   {'entities': [[43, 46, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [130, 133, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Male offspring with ancestral EDC exposure present with reduced fertility and dysfunctional spermatozoa, whereby spermatozoa are metabolically stressed, lack DNA integrity and present with permanent epigenetic alterations.\r',
#   {'entities': [[30, 33, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Across generations, male and female offspring demonstrate distinct patterns of reproductive characteristics, depending upon the specific lineage of EDC exposure.\r',
#   {'entities': [[148, 151, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Our results illustrate how dietary EDCs present in agricultural plants could promote transgenerational subfertility and contribute to declining insect populations.\r',
#   {'entities': [[35, 39, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Mammalian embryos are very vulnerable to environmental toxicants (ETs) exposure.\r',
#   {'entities': [[41, 64, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [66, 69, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Bisphenol A (BPA), one of the most diffused ETs, exerts endocrine-disrupting effects through estro-gen-mimicking and hormone-like properties, with detrimental health effects, including on reproduction.\r',
#   {'entities': [[0, 11, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [13, 16, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [44, 47, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  ['This study, using gastruloids as a 3D stem cell-based in vitro model of embryonic development, showed that BPA exposure arrests their axial elongation when present during the Wnt/β-catenin pathway activation period by β-catenin protein reduction.\r',
#   {'entities': [[107, 110, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [218, 227, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  ['Also, the lack of gastruloids elongation might be related to altered exit of BPA-exposed cells from the pluripotency condition and their following differentiation.\r',
#   {'entities': [[77, 88, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ["In conclusion, here we show that the inhibition of gastruloids' axial elongation by BPA might be the result of the concomitant Wnt/β-catenin perturbation, reduced N-cadherin expression and Oct4, T/Bra and Cdx2 altered patter expression, which all together concur in the impaired development of mouse gastruloids.\r",
#   {'entities': [[84, 87, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Evidence from animal experiments and epidemiological studies has reported controversial results about the effects of prenatal bisphenols (BPs) exposure on childhood thyroid function.\r',
#   {'entities': [[126, 136, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [138, 141, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [165, 172, 'TARGET']]}],
#  ['This study aims to explore the associations of prenatal exposure to BPs with thyroid-related hormones (THs) in newborns and early childhood, with a particular focus on the sex-dependent and exposure level effects.\r',
#   {'entities': [[68, 71, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [77, 101, 'TARGET'],
#     [103, 106, 'TARGET']]}],
#  None,
#  ['The exposures assessed include bisphenol A (BPA), bisphenol F (BPF), bisphenol S (BPS), bisphenol AF (BPAF), and tetrachlorobisphenol A (TCBPA).\r',
#   {'entities': [[31, 42, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [44, 47, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [50, 61, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [63, 66, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [69, 80, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [82, 85, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [88, 100, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [102, 106, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [113, 135, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [137, 142, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['THs measured were thyroid stimulating hormone (TSH), total tri-iodothyronine (TT3), total thyroxine (TT4), free tri-iothyronine (FT3), and free thyroxine (FT4).\r',
#   {'entities': [[18, 45, 'TARGET'],
#     [47, 50, 'TARGET'],
#     [59, 76, 'TARGET'],
#     [78, 81, 'TARGET'],
#     [84, 99, 'TARGET'],
#     [101, 104, 'TARGET'],
#     [107, 127, 'TARGET'],
#     [129, 132, 'TARGET'],
#     [139, 153, 'TARGET'],
#     [155, 158, 'TARGET']]}],
#  None,
#  None,
#  None,
#  None,
#  ['Prenatal bisphenol concentrations were statistically significant related to alterations in thyroid hormones in children, exclusively in female offspring, including reduced TSH (β = -0.020, 95% CI: -0.036, -0.005) and increased TT3 levels (β = 0.011, 95% CI: 0.001, 0.021), and exposure to high concentration of bisphenols (>1.5 ug/g creatinine) significantly reduced FT3 levels in children (β = -0.011, 95% CI: -0.020, -0.003).\r',
#   {'entities': [[9, 18, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [91, 107, 'TARGET'],
#     [172, 175, 'TARGET'],
#     [227, 230, 'TARGET'],
#     [311, 321, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [367, 370, 'TARGET']]}],
#  ['Prenatal bisphenol exposure is linked to alterations in thyroid hormone levels in girls, necessitating enhanced measures to control bisphenol exposure levels during pregnancy for child health protection.\r',
#   {'entities': [[9, 18, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [56, 71, 'TARGET']]}],
#  None,
#  None,
#  ['Among these, it has been recognized as an endocrine disruptor.\r',
#   {'entities': [[42, 61, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['This work aimed to test the effects and potential endocrine disrupting action of glyphosate on PNT1A human prostate cells, an immortalized non-tumor epithelial cell line, possessing both ERα and ERβ estrogen receptors.\r',
#   {'entities': [[81, 91, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [95, 100, 'TARGET'],
#     [187, 190, 'TARGET'],
#     [195, 198, 'TARGET'],
#     [199, 217, 'TARGET']]}],
#  ['The results showed that glyphosate induces cytotoxicity, mitochondrial dysfunction, and rapid activation of ERα and ERβ via nuclear translocation.\r',
#   {'entities': [[24, 34, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [108, 111, 'TARGET'],
#     [116, 119, 'TARGET']]}],
#  None,
#  None,
#  None,
#  ['Finally, the results of immunofluorescence analysis demonstrated that glyphosate acts as an estrogen disruptor determining the nuclear translocation of both ERs.\r',
#   {'entities': [[70, 80, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [92, 110, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [157, 160, 'TARGET']]}],
#  None,
#  ['In conclusion, the results collected show that in non-tumor prostate cells glyphosate can cause cell death and acts as a xenoestrogen, activating estrogen receptors.\r',
#   {'entities': [[75, 85, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [146, 164, 'TARGET']]}],
#  None,
#  None,
#  ['The ATP-binding cassette transporter breast cancer resistance protein (Bcrp) reduces drug delivery across the BBB by actively transporting its clinical substrates back into peripheral circulation before their entry into the CNS compartment.\r',
#   {'entities': [[37, 69, 'TARGET'], [71, 75, 'TARGET']]}],
#  ['17β-Estradiol (E2)-elicited changes in Bcrp transport activity and expression have been documented previously.\r',
#   {'entities': [[0, 13, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [15, 17, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [39, 43, 'TARGET']]}],
#  ['We report a novel signaling mechanism by which E2 decreases Bcrp transport activity in mouse brain capillaries via rapid nongenomic signaling through estrogen receptor α.\r',
#   {'entities': [[47, 49, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [60, 64, 'TARGET'],
#     [150, 169, 'TARGET']]}],
#  ['We extended this finding to investigate the effects of different endocrine-disrupting compounds (EDCs) and selective estrogen receptor modulators (SERMs) on Bcrp transport function.\r',
#   {'entities': [[65, 95, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [97, 101, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [107, 145, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [147, 152, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [157, 161, 'TARGET']]}],
#  ['We also demonstrate sex-dependent expression of Bcrp and E2-sensitive Bcrp transport activity at the BBB ex vivo.\r',
#   {'entities': [[48, 52, 'TARGET'], [70, 74, 'TARGET']]}],
#  ['This work establishes an explanted tissue-based model by which to interrogate EDCs and SERMs as modulators of nongenomic estrogenic signaling with implications for sex and hormonal regulation of therapeutic delivery into the CNS.\r',
#   {'entities': [[78, 82, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [87, 92, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Endocrine disrupting chemicals (EDCs) are known to interfere with endocrine homeostasis.\r',
#   {'entities': [[0, 30, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [32, 36, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  ['This applies in particular to the ubiquitously available bisphenols A (BPA), F (BPF), and S (BPS).\r',
#   {'entities': [[57, 69, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [71, 74, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [80, 83, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [93, 96, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['NCI-H295R adrenocortical cells were exposed to different concentrations (1nM-1mM) of BPA, BPF, BPS, and an equimolar mixture of them (BPmix).\r',
#   {'entities': [[85, 88, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [90, 93, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [95, 98, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['After 72 hours, 15 endogenous steroids were measured using LC-MS/MS.\r',
#   {'entities': [[19, 38, 'TARGET']]}],
#  None,
#  None,
#  ['Cell viability remained unaffected at bisphenol concentrations lower than 250 µM.\r',
#   {'entities': [[38, 47, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['All tested bisphenols and their combination led to extensive alterations in the quantified steroid levels.\r',
#   {'entities': [[11, 21, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['The most profound fold changes (FC) in steroid concentrations after exposure to BPA (>10µM) were seen for androstenedione, e.g.\r',
#   {'entities': [[80, 83, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  ['For BPF, levels of 17-hydroxyprogesterone were significantly increased by 25µM (FC 2.57±0.49, p≤0.001) and 50µM (FC 2.65±0.61, p≤0.0001).\r',
#   {'entities': [[4, 7, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['BPS treatment led to a dose-dependent decrease of 11-deoxycorticosterone at >1µM (e.g.\r',
#   {'entities': [[0, 3, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  None,
#  ['11-deoxycortisosterone was decreased at doses >10µM (FC 0.27±0.04, p≤0.0001, at 25µM), whereas 21-deoxycortisol was increased by 2.92±0.20 (p≤0.01) at 10µM, and by 3.21±0.45 (p≤0.001) at 50µM.\r',
#   {'entities': []}],
#  ['While every measured androgen (DHEA, DHEAS, androstenedione, testosterone, DHT) was lowered in all experiments, estradiol levels were significantly increased by BPA, BPF, BPS, and BPmix (e.g.\r',
#   {'entities': [[161, 164, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [166, 169, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [171, 174, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  ['Calculated substrate-product ratios indicated an inhibition of CYP17A1-, and CYP21A2 mediated conversions, whereas CYP11B1 and CYP19A1 showed higher activity in the presence of bisphenols.\r',
#   {'entities': [[63, 71, 'TARGET'],
#     [77, 84, 'TARGET'],
#     [115, 122, 'TARGET'],
#     [127, 134, 'TARGET'],
#     [177, 187, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Based on these findings, most relevant mRNA expression of CYP genes were analysed.\r',
#   {'entities': [[58, 67, 'TARGET']]}],
#  ['mRNA levels of StAR, CYP11B1, and CYP17A1 were significantly increased by BPF, BPS, and BPmix.\r',
#   {'entities': [[15, 19, 'TARGET'],
#     [21, 28, 'TARGET'],
#     [34, 41, 'TARGET'],
#     [74, 77, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [79, 82, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['In cell culture, bisphenols interfere with steroidogenesis at non-cytotoxic levels, leading to compound-specific patterns of significantly altered hormone levels.\r',
#   {'entities': [[17, 27, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['These results justify and call for additional in-vivo studies to evaluate effects of EDCs on adrenal gland functionality.\r',
#   {'entities': [[85, 89, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  ['The reproductive function of females is a well-known target of endocrine-disrupting chemicals.\r',
#   {'entities': [[63, 93, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['Among the 7 steroidogenic enzymes tested, an isolated higher expression of Cyp19a1 was measured in F rabbits ovaries.\r',
#   {'entities': [[75, 82, 'TARGET']]}],
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['A Structured Expert Judgment (Research Outreach, 2021) process was performed to provide plausible estimates of health impacts for 16 commonly found pollutants: asbestos, arsenic, benzene, chromium, cadmium, dioxins, fluoride, highly hazardous pesticides (HHPs), lead, mercury, polycyclic-aromatic hydrocarbons (PAHs), polychlorinated biphenyls (PCBs), Per- and Polyfluorinated Substances (PFAs), phthalates, endocrine disrupting chemicals (EDCs), and brominated flame retardants (BRFs).\r',
#   {'entities': [[160, 168, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [170, 177, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [179, 186, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [188, 196, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [198, 205, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [207, 214, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [216, 224, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [226, 253, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [255, 259, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [262, 266, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [268, 275, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [277, 309, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [311, 315, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [318, 343, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [345, 349, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [361, 387, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [389, 393, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [396, 406, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [408, 438, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [440, 444, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [451, 478, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [480, 484, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  ['The foremost substances, in terms of mean projected annual total deaths, were lead, asbestos, arsenic, and HHPs.\r',
#   {'entities': [[78, 82, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [84, 92, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [94, 101, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [107, 111, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  None,
#  None,
#  None,
#  ['Based on the evidence available, experts concluded some of the more notorious chemical pollutants, such as PCBs and dioxin, do not result in high levels of human health impact from a global scale perspective.\r',
#   {'entities': [[107, 111, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [116, 122, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['However, the chemical toxicity of some compounds released in recent decades, such as Endocrine Disrupters and PFAs, cannot be ignored, even if current impacts are limited.\r',
#   {'entities': [[85, 105, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [110, 114, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  None,
#  None,
#  None,
#  ['Bisphenols (BP), including BPA and "BPA-free" structural analogs, are commonly used plasticizers that are present in many plastics and are known endocrine disrupting chemicals.\r',
#   {'entities': [[0, 10, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [12, 14, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [27, 30, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [84, 96, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [122, 130, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [145, 175, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Prenatal exposure to BPA has been associated with negative neurodevelopmental and behavioral outcomes in children and in rodent models.\r',
#   {'entities': [[21, 24, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Prenatal BPA exposure has also been shown to impair postnatal maternal care provisioning, which can also affect offspring neurodevelopment and behavior.\r',
#   {'entities': [[9, 12, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['However, there is limited knowledge regarding the biological effects of prenatal exposure to bisphenols other than BPA and the interplay between prenatal bisphenol exposure and postnatal maternal care on adult behavior.\r',
#   {'entities': [[93, 103, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [115, 118, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [154, 163, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['The purpose of the current study was to determine the interactive impact of prenatal bisphenol exposure and postnatal maternal care on neurodevelopment and behavior in rats.\r',
#   {'entities': [[85, 94, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Our findings suggest that the effects of prenatal bisphenol exposure on eye-opening, adult attentional set shifting and anxiety-like behavior in the open field are dependent on maternal care in the first five days of life.\r',
#   {'entities': [[50, 59, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Interestingly, maternal care might also attenuate the effects of prenatal bisphenol exposure on eye opening and adult attentional set shifting.\r',
#   {'entities': [[74, 83, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Finally, transcriptomic profiles in male and female medial prefrontal cortex and amygdala suggest that the interactive effects of prenatal bisphenol exposure and postnatal maternal care converge on estrogen receptor signaling and are involved in biological processes related to gene expression and protein translation and synthesis.\r',
#   {'entities': [[139, 148, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [198, 215, 'TARGET']]}],
#  ['Overall, these findings indicate that postnatal maternal care plays a critical role in the expression of the effects of prenatal bisphenol exposure on neurodevelopment and adult behavior.\r',
#   {'entities': [[129, 138, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  ['Sex and thyroid hormones are critical for male reproductive health.\r',
#   {'entities': [[8, 24, 'TARGET']]}],
#  ['However, the associations between haloacetic acid (HAA) exposure - a known endocrine disruptor - and sex and thyroid hormones in humans remains unclear.\r',
#   {'entities': [[34, 49, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [51, 54, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [75, 94, 'TARGET'],
#     [109, 125, 'TARGET']]}],
#  None,
#  ['We measured concentrations of sex and thyroid hormones in a single blood sample and dichloroacetic acid (DCAA) and trichloroacetic acid (TCAA) in repeated urine samples.\r',
#   {'entities': [[84, 103, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [105, 109, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [115, 135, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [137, 141, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Multivariable linear regression models were constructed to evaluate the associations between HAA concentrations and hormone measurements.\r',
#   {'entities': [[93, 96, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['After adjusting for potential confounders and urinary creatinine concentrations, urinary concentrations of TCAA were inversely associated with serum levels of sex hormone-binding globulin (SHBG), testosterone (T), T/luteinizing hormone ratio (T/LH), and thyroid stimulating hormone (TSH) (all P for trend\xa0<\xa00.10).\r',
#   {'entities': [[107, 111, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [159, 187, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [189, 193, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [254, 281, 'TARGET'],
#     [283, 286, 'TARGET']]}],
#  ['Compared with participants in the lowest quartile of TCAA concentrations, those in the highest quartile had reduced serum levels of SHGB by 14.2\xa0% (95% CI: -26.7, -3.0\xa0%), T by 11.1\xa0% (95% CI: -21.7, -1.3\xa0%), T/LH by 21.0\xa0% (95% CI: -36.7, -7.1\xa0%), and TSH by 19.1\xa0% (95% CI: -39.7, -1.5\xa0%).\r',
#   {'entities': [[53, 57, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [132, 136, 'TARGET']]}],
#  ['Additionally, we observed inverse associations between continuous measurements of urinary HAAs and serum levels of free T, bioactive T, and estradiol.\r',
#   {'entities': [[90, 94, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Our findings suggest that male HAA exposure may be associated with disrupted sex and thyroid function.\r',
#   {'entities': [[31, 34, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [85, 92, 'TARGET']]}],
#  None,
#  ['It is crucial to develop and validate suitable in vitro assays capable of measuring the disruption of the thyroid hormone (TH) system.\r',
#   {'entities': [[106, 121, 'TARGET']]}],
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['Prenatal exposure to ubiquitous endocrine-disrupting chemicals (EDCs) may increase the risk of metabolic syndrome (MetS) in children, but few studies have studied chemical mixtures or explored underlying protein and metabolic signatures.\r',
#   {'entities': [[32, 62, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [64, 68, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['To investigate associations of prenatal exposure to EDC mixtures with MetS risk score in children and identify associated proteins and metabolites.\r',
#   {'entities': [[52, 55, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  ['Eligible participants included mother-child pairs with measured prenatal EDC exposures and complete data on childhood MetS risk factors, proteins, and metabolites.\r',
#   {'entities': [[73, 76, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  ['Nine metals, 3 organochlorine pesticides, 5 polychlorinated biphenyls, 2 polybrominated diphenyl ethers (PBDEs), 5 perfluoroalkyl substances (PFAS), 10 phthalate metabolites, 3 phenols, 4 parabens, and 4 organophosphate pesticide metabolites measured in urine and blood samples collected during pregnancy.\r',
#   {'entities': [[15, 40, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [44, 69, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [73, 103, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [105, 110, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [115, 140, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [142, 146, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [152, 161, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [177, 184, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [188, 196, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [204, 229, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  None,
#  None,
#  None,
#  ['MetS score increased per 1-quartile increase of the mixture for metals (β\u2009=\u20090.44; 95% credible interval [CrI], 0.30 to 0.59), organochlorine pesticides (β\u2009=\u20090.22; 95% CrI, 0.15 to 0.29), PBDEs (β\u2009=\u20090.17; 95% CrI, 0.06 to 0.27), and PFAS (β\u2009=\u20090.19; 95% CrI, 0.14 to 0.24).\r',
#   {'entities': [[64, 70, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [126, 151, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [187, 192, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [232, 236, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['High-molecular weight phthalate mixtures (β\u2009=\u2009-0.07; 95% CrI, -0.10 to -0.04) and low-molecular weight phthalate mixtures (β\u2009=\u2009-0.13; 95% CrI, -0.18 to -0.08) were associated with a decreased MetS score.\r',
#   {'entities': [[22, 31, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [103, 112, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Most EDC mixtures were associated with elevated proinflammatory proteins, amino acids, and altered glycerophospholipids, which in turn were associated with increased MetS score.\r',
#   {'entities': [[5, 8, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['This cohort study suggests that prenatal exposure to EDC mixtures may be associated with adverse metabolic health in children.\r',
#   {'entities': [[53, 56, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Given the pervasive nature of EDCs and the increase in MetS, these findings hold substantial public health implications.\r',
#   {'entities': [[30, 34, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['17α-estradiol, a less potent naturally occurring isomer of 17β-estradiol, was detected only in follicular fluid.\r',
#   {'entities': [[0, 13, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [59, 72, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  ['Furthermore, ratios of specific steroid hormones showed higher estradiol/ testosterone and estrone/androstenedione (indicating higher CYP19A1 activity, p\u2009<\u20090.01) and higher 17-hydroxyprogesterone/progesterone and dehydroepiandrosterone /androstenedione (indicating higher CYP17A1 activity, p\u2009<\u20090.01) in fetal compared to adult ovarian tissue cultures.\r',
#   {'entities': [[134, 141, 'TARGET'], [272, 279, 'TARGET']]}],
#  None,
#  None,
#  ['Phthalates are ubiquitous endocrine disruptors.\r',
#   {'entities': [[0, 10, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [26, 46, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  None,
#  None,
#  ['On the same day, women provided a serum sample during controlled ovarian stimulation, which was analyzed for metabolomics using liquid chromatography coupled with high-resolution mass spectrometry and two chromatography columns, and a urine sample, which was analyzed for 11 phthalate metabolites using targeted approaches.\r',
#   {'entities': [[275, 284, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  None,
#  ['Metabolic pathway enrichment analysis revealed 43 pathways in the C18 negative and 32 pathways in the HILIC positive columns that were significantly associated (p\xa0<\xa00.05) with at least one of the 11 urinary phthalate metabolites or molar sum of di-2-ethylhexyl phthalate metabolites.\r',
#   {'entities': [[207, 216, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [245, 270, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Lipid, amino acid, and carbohydrate metabolism were the most common pathways associated with phthalate exposure.\r',
#   {'entities': [[93, 102, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  ['Our study provides further insight into the metabolites and metabolomics pathways, including amino acid, lipid, and vitamin metabolism that may underlie the observed associations between phthalate exposures and lower fertility in women.\r',
#   {'entities': [[187, 196, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Endocrine-disrupting chemicals may play a role in adiposity development during childhood.\r',
#   {'entities': [[0, 30, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  None,
#  ['We studied the associations of four phenols, four parabens, seven phthalates, and one nonphthalate plasticizer from weekly pooled urine samples collected from the mother during second and third trimesters (median 18 and 34 gestational weeks, respectively) and infant at 2 and 12 months of age, and child growth until 36 months.\r',
#   {'entities': [[36, 43, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [50, 58, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [66, 76, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [86, 110, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  None,
#  None,
#  ['Bisphenol S (BPS) at second trimester was positively associated with all infant growth parameters at 3 and 36 months, with similar patterns between exposure at third trimester and all infant growth parameters at 3 months.\r',
#   {'entities': [[0, 11, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [13, 16, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Mono-n-butyl phthalate (MnBP) at 12 months was positively associated with body mass index (BMI), weight, and head circumference at 36 months.\r',
#   {'entities': [[0, 22, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [24, 28, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Mixture analysis revealed positive associations between exposure at 12 months and BMI and weight at 36 months, with MnBP showing the highest effect size within the mixture.\r',
#   {'entities': [[116, 120, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  ['Furthermore, this study highlighted the impact of BPS, a compound replacing bisphenol A, which has never been studied in this context.\r',
#   {'entities': [[50, 53, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [76, 87, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  None,
#  ['Growing evidence suggests environmental exposures, including endocrine-disrupting chemicals (EDCs), are associated with an increased risk of pregnancy complications that are associated with long-term cardiometabolic risk.\r',
#   {'entities': [[61, 91, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [93, 97, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['However, the impact of perinatal EDC exposure on subsequent cardiometabolic risk post-pregnancy is less understood.\r',
#   {'entities': [[33, 36, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['Participant pregnancy and postpartum urinary phthalate metabolite concentrations and postpartum glycaemic biomarkers were quantified.\r',
#   {'entities': [[45, 54, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['To date, studies within ERGO found higher exposure to phthalates and phthalate mixtures, and separately, higher exposure to radioactive ambient particulate matter, were associated with adverse gestational glycaemic outcomes.\r',
#   {'entities': [[54, 64, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [69, 78, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Additionally, certain personal care products used in pregnancy, notably hair oils, were associated with higher urinary phthalate metabolite concentrations, earlier gestational age at delivery and lower birth weight.\r',
#   {'entities': [[22, 44, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [72, 81, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [119, 128, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  ['For endocrine disrupting chemicals (EDC) the existence of "safe exposure levels", that is exposure levels that do not present an appreciable risk to human health is most controversially discussed, as is the existence of health-based reference values.\r',
#   {'entities': [[4, 34, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [36, 39, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Concerns have been especially raised that EDCs might not possess a threshold level such that no exposure level to EDCs can be considered safe.\r',
#   {'entities': [[42, 46, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [114, 118, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['To explore whether or not threshold levels can be identified, we performed a screening exercise on 14 pesticidal and biocidal active substances previously identified as EDCs in the European Union.\r',
#   {'entities': [[117, 143, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [169, 173, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  ['Dimethomorph, metiram and propiconazole for which the weight of evidence demonstrating endocrine disruption was the strongest were used as subjects for further study.\r',
#   {'entities': [[0, 12, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [14, 21, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [26, 39, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  None,
#  None,
#  ['As a proof of concept this study provides evidence that like other substances of toxicological concern EDCs have threshold levels for adversity.\r',
#   {'entities': [[103, 107, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['While for some EDCs the respective thresholds might indeed be very low this shows that, data allowing, for other EDCs sufficiently protective reference values can be derived.\r',
#   {'entities': [[15, 19, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [113, 117, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['The endocrine system functions by interactions between ligands and receptors.\r',
#   {'entities': [[67, 76, 'TARGET']]}],
#  ['Ligands exhibit potency for binding to and interacting with receptors.\r',
#   {'entities': [[60, 69, 'TARGET']]}],
#  None,
#  None,
#  None,
#  None,
#  ['We previously identified the minimum ligand potency required to produce clinically observable estrogenic agonist effects via the human estrogen receptor-alpha (ERα).\r',
#   {'entities': [[135, 158, 'TARGET'], [160, 163, 'TARGET']]}],
#  ['By examining data on botanical estrogens and dietary supplements, we demonstrated that ERα ligands with potency lower than one one-thousandth that of the primary endogenous hormone 17β-estradiol (E2) do not produce clinically observable estrogenic effects.\r',
#   {'entities': [[87, 90, 'TARGET'],
#     [181, 194, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [196, 198, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['This allowed us to propose a Human-Relevant Potency Threshold (HRPT) for ERα ligands of 1\u2009×\u200910-4 relative to E2.\r',
#   {'entities': [[73, 76, 'TARGET'],
#     [109, 111, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Here, we test the hypothesis that the HRPT for ERα arises from the receptor occupancy by the normal metabolic milieu of endogenous ERα ligands.\r',
#   {'entities': [[47, 50, 'TARGET'],
#     [131, 142, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  ['We have calculated fractional receptor occupancies for ERα ligands with potencies below and above the previously established HRPT when normal circulating levels of some endogenous ERα ligands and E2 were also present.\r',
#   {'entities': [[30, 38, 'TARGET'],
#     [55, 66, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [180, 191, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [196, 198, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Fractional receptor occupancy calculations showed that individual ERα ligands with potencies more than tenfold higher than the HRPT can compete for occupancy at ERα against individual components of the endogenous metabolic milieu and against mixtures of those components at concentrations found naturally in human blood.\r',
#   {'entities': [[11, 19, 'TARGET'],
#     [66, 77, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [161, 164, 'TARGET']]}],
#  ['Ligands with potencies less than tenfold higher than the HRPT were unable to compete successfully for ERα.\r',
#   {'entities': [[0, 7, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [102, 105, 'TARGET']]}],
#  ['These results show that the HRPT for ERα agonism (10-4 relative to E2) proposed previously is quite conservative and should be considered strong evidence against the potential for disruption of the estrogenic pathway.\r',
#   {'entities': [[37, 40, 'TARGET']]}],
#  ['For chemicals with potency 10-3 of E2, the potential for estrogenic endocrine disruption must be considered equivocal and subject to the presence of corroborative evidence.\r',
#   {'entities': [[35, 37, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Most importantly, this work demonstrates that the endogenous metabolic milieu is responsible for the observed ERα agonist HRPT, that this HRPT applies also to ERα antagonists, and it provides a compelling mechanistic explanation for the HRPT that is grounded in basic principles of molecular kinetics using well characterized properties and concentrations of endogenous components of normal metabolism.\r',
#   {'entities': [[110, 121, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [159, 174, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Recent evidence has revealed associations between endocrine-disrupting chemicals (EDCs) and placental insufficiency due to altered placental growth, syncytialization, and trophoblast invasion.\r',
#   {'entities': [[50, 80, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [82, 86, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['However, no epidemiologic study has reported associations between exposure to EDCs and asymmetric fetal growth restriction (FGR) caused by placenta insufficiency.\r',
#   {'entities': [[78, 82, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  None,
#  ['Maternal urine and cord blood samples were collected, and the levels of bisphenol-A (BPA), monoethyl phthalates, and perfluorooctanoic acid in each specimen were analyzed.\r',
#   {'entities': [[72, 83, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [85, 88, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [91, 111, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [117, 139, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['We investigated linear and non-linear associations between the levels of EDCs and fetal growth parameters, including the head circumference (HC)/abdominal circumference (AC) ratio as an asymmetric parameter.\r',
#   {'entities': [[73, 77, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['The levels of EDCs were compared between fetuses with and without asymmetric FGR.\r',
#   {'entities': [[14, 18, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Of the EDCs, only the fetal levels of BPA showed a linear association with the HC/AC ratio after adjusting for confounding variables (β\u2009=\u20090.003, p\u2009<\u20090.05).\r',
#   {'entities': [[7, 11, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [38, 41, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['When comparing the normal growth and asymmetric FGR groups, the asymmetric FGR group showed significantly higher maternal and fetal BPA levels compared to the normal growth group (maternal urine BPA, 3.99\u2009μg/g creatinine vs. 1.71\u2009μg/g creatinine [p\u2009<\u20090.05]; cord blood BPA, 1.96\u2009μg/L vs. -0.86\u2009μg/L [p\u2009<\u20090.05]).\r',
#   {'entities': [[132, 135, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [269, 272, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['In conclusion, fetal exposure levels of BPA show linear associations with asymmetric fetal growth patterns.\r',
#   {'entities': [[40, 43, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['High maternal and fetal exposure to BPA might be associated with asymmetric FGR.\r',
#   {'entities': [[36, 39, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Atrazine (ATR) is widely used worldwide as a commercial herbicide, Diaminochlorotriazine (DACT) is the main metabolite of ATR in the organism.\r',
#   {'entities': [[0, 8, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [10, 13, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [56, 65, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [67, 88, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [90, 94, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [122, 125, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['Meanwhile, ATR interfered with the expression of key factors in the steroid synthesis pathway, inducing the secretion of the sex hormones E2 and P in GCs.\r',
#   {'entities': [[11, 14, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [138, 140, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  ['Furthermore, the Nrf2/ARE pathway as a potential target to ameliorate ATR-induced endocrine disruption in GCs for proper reproductive functions.\r',
#   {'entities': [[17, 33, 'TARGET'],
#     [70, 81, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Our research provides a new perspective for understanding the effects of ATR on reproductive functions in birds.\r',
#   {'entities': [[73, 76, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['17β-estradiol (E2) is a natural endocrine disruptor that is frequently detected in surface and groundwater sources, thereby threatening ecosystems and human health.\r',
#   {'entities': [[0, 13, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [15, 17, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [32, 51, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  ['The novel gene cluster ean was found to be responsible for E2 degradation through the 4,5-seco pathway, where E2 is converted to estrone (E1) by EanA, which belongs to the short-chain dehydrogenases/reductases (SDR) superfamily.\r',
#   {'entities': [[59, 61, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [110, 112, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [129, 136, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['A three-component oxygenase system (including the P450 monooxygenase EanB1, the small iron-sulfur protein ferredoxin EanB2, and the ferredoxin reductase EanB3) was responsible for hydroxylating E1 to 4-hydroxyestrone (4-OH-E1).\r',
#   {'entities': [[194, 196, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['These results refine research on genes involved in E2 degradation and enrich the understanding of the cleavages of ring A and ring B of E2.IMPORTANCESteroid estrogens have been detected in diverse environments, ranging from oceans and rivers to soils and groundwater, posing serious risks to both human health and ecological safety.\r',
#   {'entities': [[51, 53, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['The analysis was part of a larger cohort study to determine associations between exposure to EDCs and in vitro fertilization (IVF) outcomes.\r',
#   {'entities': [[93, 97, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  ['Demographics and data on exposure to EDCs were self-reported by the participants using a questionnaire.\r',
#   {'entities': [[37, 41, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['The concentrations of estradiol (E2), progesterone (PG), anti-Mullerian hormone (AMH), and inhibin B, as well as that of 12 phthalate metabolites and 12 phenolic chemicals were measured in each FF sample.\r',
#   {'entities': [[33, 35, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [124, 133, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [153, 171, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  None,
#  None,
#  ['Most of the phthalates and phenolic substances monitored (21/24, 88%) were identified in FF.\r',
#   {'entities': [[12, 22, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Ten compounds (7 phthalate metabolites, 3 phenols) were found in more than 50% of samples.\r',
#   {'entities': [[17, 26, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [42, 49, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['In addition, there were positive associations between E2 levels and mono-n-butyl phthalate (MnBP) (beta\u2009=\u20090.01) and mono-isobutyl phthalate (MiBP) (beta\u2009=\u20090.03) levels (q value\u2009<\u20090.05).\r',
#   {'entities': [[54, 56, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [68, 90, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [92, 96, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [116, 139, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [141, 145, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Higher concentrations of several phthalate metabolites, present among others in personal care products, were associated with increased E2 levels in FF.\r',
#   {'entities': [[80, 102, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [135, 137, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['The results emphasize the need to further investigate the mechanisms of action of such EDCs on hormonal cyclicity and fertility in women.\r',
#   {'entities': [[87, 91, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  None,
#  None,
#  ['Since enamel does not remodel after formation, it may serve as a permanent record of insults during organ development.Our primary purpose was to investigate any possible relationship between intrauterine exposure to endocrine disrupting chemicals (phenols and phthalates) and developmental defects in enamel in children, while also accounting for fluoride exposure.\r',
#   {'entities': [[216, 246, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [248, 255, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [260, 270, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [301, 307, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [347, 355, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  None,
#  None,
#  None,
#  ['Perinatal maternal urine samples were assessed for the concentration of fluoride, phenols and phthalates, including bisphenol A (BPA).Pairwise statistical analyses were done to correlate the dental findings with one another and with the presence of environment chemicals found in the urine samples.\r',
#   {'entities': [[72, 80, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [82, 89, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [94, 104, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [116, 127, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [129, 132, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  ['No consistent correlations were seen between dental findings and the presence of phenols and phthalates in prenatal urine, but the number of samples available for the assessment was limited (n\u2009=\u200935).In conclusion, we found a high proportion of dental hypomineralization in a population based paediatric cohort, but did not find an association with prenatal exposure to phenols and phthalates.\r',
#   {'entities': [[81, 88, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [93, 103, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [369, 376, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [381, 391, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Endocrine-disrupting chemicals (EDCs) may impact the development of prostate cancer (PCa) by altering the steroid metabolism.\r',
#   {'entities': [[0, 30, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [32, 36, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Although their exact mechanism of action in controlling tumor growth is not known, EDCs may inhibit steroidogenic enzymes such as CYP17A1 or CYP19A1 which are involved in the production of androgens or estrogens.\r',
#   {'entities': [[83, 87, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [130, 137, 'TARGET'],
#     [141, 148, 'TARGET']]}],
#  None,
#  ['Essential oils or their metabolites, like lavender oil and tea tree oil, have been reported to act as potential EDCs and contribute towards sex steroid imbalance in cases of prepubertal gynecomastia in boys and premature thelarche in girls due to the exposure to lavender-based fragrances.\r',
#   {'entities': [[112, 116, 'TARGET']]}],
#  ['We screened a range of EO components to determine their effects on CYP17A1 and CYP19A1.\r',
#   {'entities': [[67, 74, 'TARGET'], [79, 86, 'TARGET']]}],
#  ['Computational docking was performed to predict the binding of essential oils with CYP17A1 and CYP19A1.\r',
#   {'entities': [[82, 89, 'TARGET'], [94, 101, 'TARGET']]}],
#  None,
#  ['Many of the tested compounds bind close to the active site of CYP17A1, and (+)-Cedrol had the best binding with CYP17A1 and CYP19A1.\r',
#   {'entities': [[62, 69, 'TARGET'],
#     [78, 85, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [112, 119, 'TARGET'],
#     [124, 131, 'TARGET']]}],
#  ['Eucalyptol, Dihydro-β-Ionone, and (-)-α-pinene showed 20% to 40% inhibition of dehydroepiandrosterone production; and some compounds also effected CYP19A1.\r',
#   {'entities': [[0, 10, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [12, 28, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [37, 46, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [147, 154, 'TARGET']]}],
#  ['Extensive use of these essential oils in various beauty and hygiene products is common, but only limited knowledge about their potential detrimental side effects exists.\r',
#   {'entities': [[23, 37, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  ['On the other hand, due to their effect on lowering androgen output and ability to bind at the active site of steroidogenic cytochrome P450s, these compounds may provide design ideas for novel compounds against hyperandrogenic disorders such as PCa and PCOS.\r',
#   {'entities': [[123, 133, 'TARGET'], [134, 139, 'TARGET']]}],
#  ['Organophosphate esters (OPEs) are used primarily as flame retardants and plasticizers.\r',
#   {'entities': [[0, 22, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [24, 28, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [52, 68, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [73, 85, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Previously, we reported that adrenal cells are important targets of individual OPEs.\r',
#   {'entities': [[79, 83, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['While the production of 17β-estradiol remained unaffected, a slight decrease in testosterone production was observed after stimulation.\r',
#   {'entities': [[24, 37, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['Developing alligators were incubated at female-producing temperatures with a subset of individuals being exposed to 17-α-methyltestosterone (MT) before sexual determination.\r',
#   {'entities': [[116, 139, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
# ...
#   {'entities': [[75, 78, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['Although we know a great deal about the transporter systems by which zinc and calcium pass from the blood stream into milk, the interactions and cellular localization of transporters that carry substrates such as glucose, amino acids, copper, and the many other trace metals present in human milk across plasma and intracellular membranes require more research.\r',
#   {'entities': [[69, 73, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [78, 85, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [235, 241, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [268, 274, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['We pose the question of how cultured mammary alveolar cells and animal models can help answer lingering questions about the mechanisms and regulation of human milk secretion.\r',
#   {'entities': [[54, 59, 'TARGET']]}],
#  None,
#  ['Finally, we consider the effect of medications, recreational and illicit drugs, pesticides, and endocrine-disrupting chemicals on milk secretion and composition, emphasizing that this area needs much more research attention.\r',
#   {'entities': [[80, 90, 'TARGET'], [96, 126, 'TARGET']]}],
#  ['Recent experimental and observational research has suggested that childhood allergic asthma and other conditions may be the result of prenatal exposure to environmental contaminants, such as di-(2-ethylhexyl) phthalate (DEHP).\r',
#   {'entities': [[191, 218, 'TARGET'], [220, 224, 'TARGET']]}],
#  ['In a previous epidemiological study, we found that ancestral exposure (F0 generation) to endocrine disruptors or the common plasticizer DEHP promoted allergic airway inflammation via transgenerational transmission in mice from generation F1 to F4.\r',
#   {'entities': [[89, 109, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [124, 135, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [136, 140, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['In the current study, we employed a MethylationEPIC Beadchip microarray to examine global DNA methylation in the human placenta as a function of maternal exposure to DEHP during pregnancy.\r',
#   {'entities': [[166, 170, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Interestingly, global DNA hypomethylation was observed in placental DNA following exposure to DEHP at high concentrations.\r',
#   {'entities': [[68, 71, 'TARGET'],
#     [94, 98, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Bioinformatic analysis confirmed that DNA methylation affected genes related to neurological disorders, such as autism and dementia.\r',
#   {'entities': [[38, 41, 'TARGET']]}],
#  ['These results suggest that maternal exposure to DEHP may predispose offspring to neurological diseases.\r',
#   {'entities': [[48, 52, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  ['Phthalates, a group of pervasive endocrine-disrupting chemicals found in plastics and personal care products, have been associated with a wide range of developmental and health outcomes.\r',
#   {'entities': [[0, 10, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [33, 63, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [73, 81, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [86, 108, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  ['We tested associations between prenatal exposure to 11 phthalate metabolites on epigenetic aging in children at birth, 7, 9, and 14 years of age.\r',
#   {'entities': [[55, 64, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['We hypothesized that prenatal phthalate exposure will be associated with epigenetic age acceleration measures at birth and in early childhood, with patterns dependent on sex and timing of DNAm measurement.\r',
#   {'entities': [[30, 39, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  ['Additionally, quantile g-computation was utilized to assess the effect of the phthalate mixture on GAA at birth and IEAA throughout childhood.\r',
#   {'entities': [[78, 87, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['We found a negative association between prenatal di (2-ethylhexyl) phthalate (DEHP) exposure and IEAA among males at age 7 (-0.62 years; 95% CI:-1.06 to -0.18), and a marginal negative association between the whole phthalate mixture and GAA among males at birth (-1.54 days, 95% CI: -2.79 to -0.28), while most other associations were nonsignificant.\r',
#   {'entities': [[49, 76, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [78, 82, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [215, 224, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Our results suggest that prenatal exposure to certain phthalates is associated with epigenetic aging in children.\r',
#   {'entities': [[54, 64, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  ['Polychlorinated-biphenyls (PCBs) are industrial compounds, which were widely used in manufacturing of electrical parts and transformers.\r',
#   {'entities': [[0, 25, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [27, 31, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  ['In humans and experimental model systems, PCBs elicit toxicity in part by acting as endocrine-disrupting chemicals (EDCs).\r',
#   {'entities': [[42, 46, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [84, 114, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [116, 120, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Aroclor 1221 (A1221) is a weakly estrogenic PCB mixture known to alter reproductive function in rodents.\r',
#   {'entities': [[0, 12, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [14, 19, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [44, 47, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['EDCs can impact hormone signaling at any level of the hypothalamic-pituitary-gonadal (HPG) axis, and we investigated the effects of A1221 exposure during the prenatal and postnatal developmental periods on pituitary hormone and steroid receptor expression in female rats.\r',
#   {'entities': [[0, 4, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [132, 137, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [228, 244, 'TARGET']]}],
#  ['Examining offspring at 3 ages, postnatal day 8 (P8), P32 and P60, we found that prenatal exposure to A1221 increased P8 neonate pituitary luteinizing hormone beta (Lhb) mRNA and LHβ gonadotrope cell number while decreasing LH serum hormone concentration.\r',
#   {'entities': [[101, 106, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['No changes in pituitary hormone or hormone receptor gene expression were observed peri-puberty at P32.\r',
#   {'entities': [[35, 51, 'TARGET']]}],
#  ['In reproductively mature rats at P60, we found pituitary follicle stimulating hormone beta (Fshb) mRNA levels increased by prenatal A1221 exposure with no corresponding alterations in FSH hormone or FSHβ expressing cell number.\r',
#   {'entities': [[132, 137, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Estrogen receptor alpha (ERα) mRNA and protein levels were also increased at P60, but only following postnatal A1221 dosing.\r',
#   {'entities': [[0, 23, 'TARGET'],
#     [25, 28, 'TARGET'],
#     [111, 116, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Together, these data illustrate that exposure to the PCB A1221, during critical developmental windows, alters pituitary gonadotropin hormone subunits and ERα levels in offspring at different phases of maturation, potentially impacting reproductive function in concert with other components of the HPG axis.\r',
#   {'entities': [[53, 56, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [57, 62, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [154, 157, 'TARGET']]}],
#  ['Polychlorinated biphenyls (PCBs) are organic pollutants that can have lasting impacts on offspring health.\r',
#   {'entities': [[0, 25, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [27, 31, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Here, we sought to examine maternal and fetal gene expression differences of aryl hydrocarbon receptor (AHR)-regulated genes in a mouse model of prenatal PCB126 exposure.\r',
#   {'entities': [[77, 102, 'TARGET'], [104, 107, 'TARGET']]}],
#  ['Female mice were bred and gavaged with 1 µmole/kg bodyweight PCB126 or vehicle control on embryonic days 0 and 14, and maternal and fetal tissues were collected on embryonic day 18.5.\r',
#   {'entities': [[61, 67, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  ['Interestingly, we found that the expression levels of cytochrome P450 (Cyp)1a1 and Cyp1b1 were significantly increased in response to PCB exposure in the tested maternal and fetal tissues.\r',
#   {'entities': [[54, 69, 'TARGET'],
#     [70, 78, 'TARGET'],
#     [83, 89, 'TARGET'],
#     [134, 137, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Furthermore, PCB exposure altered the expression of several other genes related to energy balance, oxidative stress, and epigenetic regulation in a manner that was less consistent across tissue types.\r',
#   {'entities': [[13, 16, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['These results indicate that maternal PCB126 exposure significantly alters gene expression in both developing fetuses and pregnant dams, and such changes vary in intensity and expressivity depending on tissue type.\r',
#   {'entities': [[37, 43, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['The altered gene expression may provide insights into pathophysiological mechanisms by which in utero PCB exposures contribute to PCB-induced postnatal metabolic diseases.\r',
#   {'entities': [[102, 105, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Estrogenic endocrine disrupting chemicals (EDCs) such as diethylstilbestrol (DES) are known to alter the timing of puberty onset and reproductive function in females.\r',
#   {'entities': [[0, 41, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [43, 47, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [57, 75, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [77, 80, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Accumulating evidence suggests that steroid synthesis inhibitors such as ketoconazole (KTZ) or phthalates may also affect female reproductive health, however their mode of action is poorly understood.\r',
#   {'entities': [[36, 64, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [73, 85, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [87, 90, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [95, 105, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Because hypothalamic activity is very sensitive to sex steroids, we aimed at determining whether and how EDCs with different mode of action can alter the hypothalamic transcriptome and GnRH release in female rats.\r',
#   {'entities': [[105, 109, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Female rats were exposed to KTZ or DES during perinatal (DES 3-6-12μg/kg.d; KTZ 3-6-12mg/kg.d), pubertal or adult periods (DES 3-12-48μg/kg.d; KTZ 3-12-48mg/kg.d).\r',
#   {'entities': [[28, 31, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [35, 38, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [57, 60, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [76, 79, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [123, 126, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [143, 146, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Ex vivo study of GnRH pulsatility revealed that perinatal exposure to the highest doses of KTZ and DES delayed maturation of GnRH secretion before puberty, whereas pubertal or adult exposure had no effect on GnRH pulsatility.\r',
#   {'entities': [[91, 94, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [99, 102, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Hypothalamic transcriptome, studied by RNAsequencing in the preoptic area and in the mediobasal hypothalamus, was found to be very sensitive to perinatal exposure to all doses of KTZ before puberty with effects persisting until adulthood.\r',
#   {'entities': [[179, 182, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Bioinformatic analysis with Ingenuity Pathway Analysis predicted "Creb signaling in Neurons" and "IGF-1 signaling" among the most downregulated pathways by all doses of KTZ and DES before puberty, and "PPARg" as a common upstream regulator driving gene expression changes.\r',
#   {'entities': [[66, 80, 'TARGET'],
#     [97, 114, 'TARGET'],
#     [169, 172, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [177, 180, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [201, 208, 'TARGET']]}],
#  ['Deeper screening ofRNAseq datasets indicated that a high number of genes regulating the activity of the extrinsic GnRH pulse generator were consistently affected by all the doses of DES and KTZ before puberty.\r',
#   {'entities': [[182, 185, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [190, 193, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  ['nRH secretion and the hypothalamic transcriptome are highly sensitive to perinatal exposure to both DES and KTZ.\r',
#   {'entities': [[100, 103, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [108, 111, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['The identified pathways should be exploredfurther to identify biomarkers for future testing strategies for EDC identification and when enhancing the current standard information requirements in regulation.\r',
#   {'entities': [[107, 110, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ["The U.S. Environmental Protection Agency's Endocrine Disruptor Screening Program (EDSP) is tasked with assessing chemicals for their potential to perturb endocrine pathways, including those controlled by androgen receptor (AR).\r",
#   {'entities': [[204, 221, 'TARGET'], [223, 225, 'TARGET']]}],
#  None,
#  None,
#  None,
#  None,
#  ['First, molecular target conservation was assessed across 585 diverse species based on the structural similarity of ARs.\r',
#   {'entities': [[115, 118, 'TARGET']]}],
#  ['These results indicate that ARs are conserved across vertebrates and are predicted to share similarly susceptibility to chemicals that interact with the human AR.\r',
#   {'entities': [[28, 31, 'TARGET'], [159, 161, 'TARGET']]}],
#  None,
#  ['Assessment of in vitro data indicates conservation of responses occurs across vertebrate ARs, with potential differences in sensitivity.\r',
#   {'entities': [[89, 92, 'TARGET']]}],
#  ['Similarly, in vivo data indicate strong conservation of the AR signaling pathways across vertebrate species, although sensitivity may vary.\r',
#   {'entities': [[60, 62, 'TARGET']]}],
#  None,
#  None,
#  ['There is considerable interest in studying the conserved design principles and functions of reproductive TRNs given that their intricate regulation is susceptible to disruption by gene mutations or exposures to exogenous endocrine disrupting chemicals (or EDCs).\r',
#   {'entities': [[221, 251, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [256, 260, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['Whereas FOXL2 was the most active gene in female humans and mice; and CYP19A1A in female zebrafish.\r',
#   {'entities': [[70, 78, 'TARGET']]}],
#  None,
#  None,
#  None,
#  None,
#  ['Hair relaxers may contain endocrine-disrupting compounds, which can harm fertility.\r',
#   {'entities': [[26, 56, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ['Non-steroidal anti-inflammatory drugs (NSAIDs) and 17α-ethinyl-estradiol (EE2) are among the most relevant endocrine-disrupting pharmaceuticals found in the environment, particularly in surface and drinking water due to their incomplete removal via wastewater treatment plants.\r',
#   {'entities': [[14, 37, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [39, 45, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [51, 72, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [74, 77, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [107, 143, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['Exposure of pregnant mice to NSAID therapeutic doses during the sex determination period has a negative impact on gonadal development and fertility in adults; however, the effects of their chronic exposure at lower doses are unknown.\r',
#   {'entities': [[29, 34, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ['In this study, we investigated the impact of chronic exposure to a mixture containing ibuprofen, 2hydroxy-ibuprofen, diclofenac, and EE2 at two environmentally relevant doses (added to the drinking water from fetal life until puberty) on the reproductive tract in F1 exposed mice and their F2 offspring.\r',
#   {'entities': [[86, 95, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [97, 115, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [117, 127, 'ENDOCRINE_DISRUPTING_CHEMICAL'],
#     [133, 136, 'ENDOCRINE_DISRUPTING_CHEMICAL']]}],
#  ...]

# %%
import pandas as pd 
import os
from tqdm import tqdm
import spacy
from spacy.tokens import DocBin
import en_ner_bionlp13cg_md

# Load the spaCy model
nlp = spacy.load("en_ner_bionlp13cg_md")

# Create the DocBin object
db = DocBin()

#There are some none entities in the annotations that need to be handled 
# Filter out None elements from the annotations list
filtered_annotations = [item for item in annotations if item is not None]

# Process the filtered annotations
for text, annot in tqdm(filtered_annotations):
    doc = nlp.make_doc(text)
    ents = []
    for start, end, label in annot['entities']:
        span = doc.char_span(start, end, label=label, alignment_mode='contract')
        if span is None:
            print("Skipping entity")
        else:
            ents.append(span)
    doc.ents = ents  # Label text with the ents
    db.add(doc)

# Change directory and save the DocBin object
os.chdir("./EDC_target_model")
db.to_disk("train.spacy")
# Out:
#   8%|▊         | 93/1145 [00:09<01:02, 16.86it/s]
# Skipping entity
# Skipping entity
# Skipping entity
# Skipping entity
#  63%|██████▎   | 720/1145 [00:10<00:00, 455.68it/s]
# Skipping entity
# Skipping entity
# 100%|██████████| 1145/1145 [00:10<00:00, 104.21it/s]
# Skipping entity
# Skipping entity
# Skipping entity

# %%
#E (Epoch):
#This column indicates the epoch number, which refers to how many #complete passes the training algorithm has made over the entire #training dataset.

# %%
# (Batch):
#This shows the batch number within the current epoch. Training is typically done in batches (subsets of the entire dataset), and this column tracks which batch is being processed.

# %%
#LOSS TOK2VEC:
#This column shows the loss value for the tok2vec component of the pipeline. The tok2vec layer is responsible for transforming the tokens into vector representations (embeddings) that can be used by the NER model.

# %%
#LOSS NER:
#This represents the loss associated with the Named Entity Recognition (NER) component. It indicates how well the model is learning to predict named entities. As training progresses, this value should generally decrease, indicating that the model is improving.

# %%
#ENTS_P (Precision for Entities):
#This shows the precision metric for the named entity predictions. Precision is the ratio of true positive named entity predictions to the total number of named entities predicted (both true positives and false positives).

# %%
#ENTS_F (F1-Score for Entities):
#The F1-score is a measure of a model's accuracy that considers both precision and recall. Specifically:

# %%
#ENTS_R (Recall for Entities):
#This shows the recall metric for the named entity predictions. Recall is the ratio of true positive named entity predictions to the total number of actual named entities in the dataset (both true positives and false negatives).

# %%
#SCORE:
#This is typically a shorthand for the overall performance score of the model on a validation set or during training, often referring to the F1-score, but it can sometimes represent another metric depending on the configuration of the training.

# %%
#table for the  ROC curve
#those are the metrics from the table that was generated by the model training

# %%
import pandas as pd

# Define the data variable
data = [
    ["E", "LOSS TOK2VEC", "LOSS NER", "ENTS_F", "ENTS_P", "ENTS_R", "SCORE"],
    [0, 0, 0.00, 17.10, 1.37, 1.25, 0.01],
    [0, 200, 251.28, 2177.45, 72.14, 78.96, 0.72],
    [1, 400, 203.89, 971.34, 84.62, 86.43, 0.85],
    [1, 600, 109.18, 838.74, 91.32, 92.87, 0.91],
    [2, 800, 138.42, 734.11, 93.26, 93.74, 0.93],
    [3, 1000, 219.72, 713.64, 94.70, 94.73, 0.95],
    [5, 1200, 232.07, 642.81, 97.10, 97.04, 0.97],
    [7, 1400, 291.06, 544.04, 97.61, 97.44, 0.98],
    [9, 1600, 357.20, 494.26, 98.54, 98.18, 0.99],
    [12, 1800, 364.83, 416.68, 99.16, 98.95, 0.99],
    [15, 2000, 462.39, 383.79, 99.02, 99.45, 0.99],
    [19, 2200, 631.86, 363.15, 99.43, 99.45, 0.99],
    [24, 2400, 567.40, 287.85, 99.81, 99.77, 1.00],
    [29, 2600, 658.22, 275.39, 99.80, 99.88, 1.00],
    [34, 2800, 455.98, 175.23, 99.84, 99.81, 1.00],
    [39, 3000, 811.45, 191.90, 99.94, 99.96, 1.00],
    [44, 3200, 379.70, 120.41, 99.88, 99.88, 1.00],
    [49, 3400, 681.01, 155.25, 99.84, 99.84, 1.00],
    [54, 3600, 545.93, 146.08, 99.92, 99.96, 1.00],
    [59, 3800, 503.62, 125.46, 99.94, 99.88, 1.00],
    [64, 4000, 700.58, 137.44, 99.94, 99.96, 1.00],
    [69, 4200, 482.59, 115.46, 99.71, 99.69, 1.00],
    [75, 4400, 737.91, 158.18, 99.88, 99.88, 1.00],
    [80, 4600, 615.42, 94.62, 99.90, 99.88, 1.00],
    [85, 4800, 596.78, 97.33, 99.92, 99.92, 1.00],
    [90, 5000, 715.43, 106.47, 99.81, 99.73, 1.00],
    [95, 5200, 786.16, 117.88, 99.96, 99.96, 1.00],
    [100, 5400, 858.02, 110.69, 99.96, 100.00, 1.00],
    [105, 5600, 943.74, 142.66, 99.92, 99.92, 1.00],
    [110, 5800, 515.02, 79.29, 99.90, 99.84, 1.00],
    [115, 6000, 710.78, 87.02, 99.90, 99.84, 1.00],
    [120, 6200, 794.46, 82.42, 99.92, 99.88, 1.00],
    [125, 6400, 1047.44, 104.75, 99.94, 99.92, 1.00],
    [130, 6600, 669.36, 100.62, 99.92, 99.92, 1.00],
    [135, 6800, 442.76, 63.37, 99.94, 99.92, 1.00],
]

# Create the DataFrame
df = pd.DataFrame(data[1:], columns=data[0])

# Display the DataFrame
print(df)

# Find the row with the highest F1 score (ENTS_F)
best_metrics = df.loc[df['ENTS_F'].idxmax()]
# Out:
#       E  LOSS TOK2VEC  LOSS NER   ENTS_F  ENTS_P  ENTS_R  SCORE
# 0     0             0      0.00    17.10    1.37    1.25   0.01
# 1     0           200    251.28  2177.45   72.14   78.96   0.72
# 2     1           400    203.89   971.34   84.62   86.43   0.85
# 3     1           600    109.18   838.74   91.32   92.87   0.91
# 4     2           800    138.42   734.11   93.26   93.74   0.93
# 5     3          1000    219.72   713.64   94.70   94.73   0.95
# 6     5          1200    232.07   642.81   97.10   97.04   0.97
# 7     7          1400    291.06   544.04   97.61   97.44   0.98
# 8     9          1600    357.20   494.26   98.54   98.18   0.99
# 9    12          1800    364.83   416.68   99.16   98.95   0.99
# 10   15          2000    462.39   383.79   99.02   99.45   0.99
# 11   19          2200    631.86   363.15   99.43   99.45   0.99
# 12   24          2400    567.40   287.85   99.81   99.77   1.00
# 13   29          2600    658.22   275.39   99.80   99.88   1.00
# 14   34          2800    455.98   175.23   99.84   99.81   1.00
# 15   39          3000    811.45   191.90   99.94   99.96   1.00
# 16   44          3200    379.70   120.41   99.88   99.88   1.00
# 17   49          3400    681.01   155.25   99.84   99.84   1.00
# 18   54          3600    545.93   146.08   99.92   99.96   1.00
# 19   59          3800    503.62   125.46   99.94   99.88   1.00
# 20   64          4000    700.58   137.44   99.94   99.96   1.00
# 21   69          4200    482.59   115.46   99.71   99.69   1.00
# 22   75          4400    737.91   158.18   99.88   99.88   1.00
# 23   80          4600    615.42    94.62   99.90   99.88   1.00
# 24   85          4800    596.78    97.33   99.92   99.92   1.00
# 25   90          5000    715.43   106.47   99.81   99.73   1.00
# 26   95          5200    786.16   117.88   99.96   99.96   1.00
# 27  100          5400    858.02   110.69   99.96  100.00   1.00
# 28  105          5600    943.74   142.66   99.92   99.92   1.00
# 29  110          5800    515.02    79.29   99.90   99.84   1.00
# 30  115          6000    710.78    87.02   99.90   99.84   1.00
# 31  120          6200    794.46    82.42   99.92   99.88   1.00
# 32  125          6400   1047.44   104.75   99.94   99.92   1.00
# 33  130          6600    669.36   100.62   99.92   99.92   1.00
# 34  135          6800    442.76    63.37   99.94   99.92   1.00

# %%
print("Best metrics based on F1 score:")
print(best_metrics)
# Out:
# Best metrics based on F1 score:
# E                  0.00
# LOSS TOK2VEC     200.00
# LOSS NER         251.28
# ENTS_F          2177.45
# ENTS_P            72.14
# ENTS_R            78.96
# SCORE              0.72
# Name: 1, dtype: float64

# %%
#learning rate 0.001

# %%
import pandas as pd
data = pd.read_csv("metrics.csv")
# Out:
#      E  LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# 0    0          0.00     17.10    1.37    1.25    1.52   0.01
# 0  200        251.28   2177.45   72.14   78.96   66.41   0.72
# 1  400        203.89    971.34   84.62   86.43   82.89   0.85
# 1  600        109.18    838.74   91.32   92.87   89.83   0.91
# 2  800        138.42    734.11   93.26   93.74   92.79   0.93

# %%
import matplotlib.pyplot as plt
epochs = data['E']
f1_score = data['ENTS_F']
precision = data['ENTS_P']
recall = data['ENTS_R']

# Plot F1 Score, Precision, and Recall
plt.figure(figsize=(10, 6))
plt.plot(epochs, f1_score, label='F1 Score', marker='o')
plt.plot(epochs, precision, label='Precision', marker='o')
plt.plot(epochs, recall, label='Recall', marker='o')
plt.xlabel('Epochs')
plt.ylabel('Percentage')
plt.title('F1 Score, Precision, and Recall over Epochs')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 epochs = data['E']
#       3 f1_score = data['ENTS_F']
#       4 precision = data['ENTS_P']
#
# TypeError: list indices must be integers or slices, not str

# %%
from sklearn.model_selection import KFold
import spacy
from spacy.training import Example

# Load your data
data = './articles.csv'  # Replace with your actual data loading

# Create k-fold cross-validation splits
kf = KFold(n_splits=5)

for train_index, test_index in kf.split(data):
    train_data = [data[i] for i in train_index]
    test_data = [data[i] for i in test_index]
    
    # Initialize a blank model
    nlp = spacy.blank("en")
    ner = nlp.add_pipe("ner")

    # Train the model
    # (Include your training code here)

    # Evaluate the model
    # (Include your evaluation code here)

    # Print or store performance metrics
    # (Include code to print/store metrics)
